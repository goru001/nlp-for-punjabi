# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pickle
PATH = '/media/gaurav/Goru/datasets/PanjabiWikipediaArticles/'
mapping_dict = {}

# %%
with open('all_panjabi_wikipedia_links.pkl', 'rb') as f:
    all_urls = pickle.load(f)
for counter, url in enumerate(all_urls):
    html_doc = ''
    with urlopen(url) as response:
        for line in response:
            line = line.decode('utf-8')
            html_doc = html_doc + line.replace('\n','')
    soup = BeautifulSoup(html_doc, 'html.parser')
    print(soup.title.string)
    paras = soup.find_all('p')
    article = ''
    for para in paras:
        article = article + para.text + '\n'
    article = re.sub(r'\([^)]*\)', r'', article)
    article = re.sub(r'\[[^\]]*\]', r'', article)
    article = re.sub(r'<[^>]*>', r'', article)
    article = re.sub(r'^https?:\/\/.*[\r\n]*', '', article)
    article = article.replace(u'\ufeff','')
    article = article.replace(u'\xa0', u' ')
    article = article.replace('  ', ' ');
    article = article.replace(' , ', ', ');
    devanagari_nums = ('०','१','२','३','४','५','६','७','८','९')
    for c, n in enumerate(devanagari_nums):
        article = re.sub(n, str(c), article)
    filename = PATH + str(counter) + '.pkl'
    mapping_dict[filename] = soup.title.string
    with open(filename, 'wb') as f:
        pickle.dump(article,f)
    print("Saved " + filename)
# Out:
# ਸ਼ਿੰਜ਼ੋ ਅਾਬੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/0.pkl
# ਦਾਰੀਓ ਫ਼ੋ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/1.pkl
# ਭਗਤ ਸਧਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/2.pkl
# ਭਾਗਸਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/3.pkl
# 1956 ਓਲੰਪਿਕ ਖੇਡਾਂ ਵਿੱਚ ਭਾਰਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/4.pkl
# ਭੌਤਿਕ ਵਿਗਿਆਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5.pkl
# ਮੰਥਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/6.pkl
# ਜੂਨੀਅਰ ਇੱਕ ਕਾਰਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/7.pkl
# ਤਰਿਸ਼ੂਲ ਪਰਬਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/8.pkl
# ਜਾਰਜੀਆ (ਦੇਸ਼) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/9.pkl
# ਆਰਿਜ ਫਾਤਿਮਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/10.pkl
# ਵਣਜਾਰਾ ਬੇਗਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/11.pkl
# ਡਾਂਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/12.pkl
# 1713 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/13.pkl
# ਵਾਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/14.pkl
# ਅਰਨਬ ਗੋਸਵਾਮੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/15.pkl
# ਲਸੂੜੀ (ਪਿੰਡ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/16.pkl
# ਆਇਸੋਲੇਟਡ ਸਿਸਟਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/17.pkl
# ਮਸਨੂਈ ਗਰਭਦਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/18.pkl
# ਭੂਗੋਲੀ ਗੁਣਕ ਪ੍ਰਬੰਧ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/19.pkl
# ਪੀ.ਐੱਚ. (ਹਾਈਡਰੋਜਨ ਸ਼ਕਤੀ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/20.pkl
# ਭੱਟ ਕੀਰਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/21.pkl
# ਮਿਆਦੀ ਪਹਾੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/22.pkl
# ਆਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/23.pkl
# ਕੈਂਬਰਿਜ ਯੂਨੀਵਰਸਿਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/24.pkl
# ਔਬਜੈਕਟਿਵ ਕੋਲੈਪਸ ਥਿਊਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/25.pkl
# ਜੂਨੀਅਰ ਇੰਜੀਨੀਅਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/26.pkl
# ਸੰਜੀਦਾ ਸ਼ੇਖ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/27.pkl
# ਕਰਿਸ ਐਵਰਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/28.pkl
# ਬਾਲ ਠਾਕਰੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/29.pkl
# ਮੀਨੂ ਮਸਾਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/30.pkl
# ਮਾਂ ਦਿਵਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/31.pkl
# ਦ ਲੋਲੈਂਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/32.pkl
# ਅੰਦਾਜ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/33.pkl
# ਜਾਪੁ ਸਾਹਿਬ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/34.pkl
# ਭੂਟਾਨ ਦਾ ਸੱਭਿਆਚਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/35.pkl
# ਉੜਾਊ ਪੁੱਤਰ ਦੀ ਵਾਪਸੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/36.pkl
# 29 ਨਵੰਬਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/37.pkl
# ਕਾਸ਼ਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/38.pkl
# ਮਨੁੱਖ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/39.pkl
# ਸਿੱਖ ਰਹਿਤ ਮਰਯਾਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/40.pkl
# ਨੇਪਾਲ ਵਿੱਚ ਕ੍ਰਿਕਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/41.pkl
# ਮਿਕਾਂਗ ਦਰਿਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/42.pkl
# ਡਾਲੀਆਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/43.pkl
# 27 ਮਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/44.pkl
# ਤਲਵੰਡੀ ਸੰਘੇੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/45.pkl
# ਸ਼ੇਖ ਅਬਦੁੱਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/46.pkl
# ਕਾਲੀ ਮੱਛਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/47.pkl
# ਪਹਿਲੀ ਸੰਸਾਰ ਜੰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/48.pkl
# ਮੀਰ ਗੁਲ ਖ਼ਾਨ ਨਸੀਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/49.pkl
# ਦੱਖਣੀ ਅਫ਼ਰੀਕੀ ਵਿਕਾਸ ਭਾਈਚਾਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/50.pkl
# ਓ. ਜੇ. ਸਿੰਪਸਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/51.pkl
# ਔਕਸੋਹੈਲਾਈਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/52.pkl
# ਸੰਸਾਰ ਵਾਤਾਵਰਨ ਦਿਵਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/53.pkl
# ਜ਼ੀਨਤ ਮਹਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/54.pkl
# ਵਡੋਦਰਾ ਐਕਸਪ੍ਰੈਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/55.pkl
# ਜੰਪਸੂਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/56.pkl
# ਵਿਭੀਸ਼ਣ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/57.pkl
# ਇਜ਼ਰਾਇਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/58.pkl
# ਨੂਰ ਅਲੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/59.pkl
# ਸ਼ਰਲੇ ਸੇਤੀਅਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/60.pkl
# ਸਿਏਰਾ ਲਿਓਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/61.pkl
# ਸੰਨ ਪੈਦਰੋ ਦੇ ਸਿਰਵਾਤੋਸ ਗਿਰਜਾਘਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/62.pkl
# 279 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/63.pkl
# ਮਾਏ ਵੈਸਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/64.pkl
# ਰਹੀਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/65.pkl
# ਕਜਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/66.pkl
# ਗੁਜਰਾਤ ਲਾਇਨਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/67.pkl
# ਲਾਈਟ ਅੱਪ ਦਾ ਵਰਲਡ ਫ਼ਾਊਂਡੇਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/68.pkl
# ਦਾਨਿਸ਼ ਤੈਮੂਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/69.pkl
# ਘਲੋਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/70.pkl
# ਵਰਜਣ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/71.pkl
# ਦੂਹੇਵਾਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/72.pkl
# ਜਰਖੇਲਾਂ ਖੇੜੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/73.pkl
# ਅਲਮੋੜਾ ਜ਼ਿਲ੍ਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/74.pkl
# ਈਲਾ ਗਾਂਧੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/75.pkl
# ਬੁੱਧਵਰਮੰਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/76.pkl
# ਬੋਮਬਾਇਲਾ ਦੇਵੀ ਲੈਸ਼ਰਾਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/77.pkl
# ਕੌਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/78.pkl
# 1790 ਦਾ ਦਹਾਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/79.pkl
# ਕਨਵਾਹ ਦੀ ਜੰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/80.pkl
# ਸਾਲਾਮਾਨਕਾ ਯੂਨੀਵਰਸਿਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/81.pkl
# ਸਾਨ ਸਿਬਾਸਤੀਆਨ ਵੱਡਾ ਗਿਰਜਾਘਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/82.pkl
# ਸ਼ੇਰ ਦੀ ਖੱਲ ਵਾਲਾ ਯੋਧਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/83.pkl
# ਕਿਸ਼ਨਪੁਰਾ (ਬੱਸੀ ਪਠਾਣਾਂ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/84.pkl
# ਕਬੀਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/85.pkl
# ਬਲਜੀਤ ਕੌਰ ਤੁਲਸੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/86.pkl
# 1780 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/87.pkl
# ਐਨੋਡੌਂਸ਼ੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/88.pkl
# ਭਾਰਤ ਵਿੱਚ ਬੁਨਿਆਦੀ ਅਧਿਕਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/89.pkl
# ਅਬਦੁਲ ਕਰੀਮ ਤੇਲਗੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/90.pkl
# ਕਾਲੀਆਂ ਹਰਨਾਂ ਰੋਹੀਏ ਫਿਰਨਾ ਪੁਸਤਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/91.pkl
# ਅਲ-ਅਨਫਾਲ ਮੁਹਿੰਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/92.pkl
# ਕਲਾ ਕੀ ਹੈ? - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/93.pkl
# ਡਗਾਣਾ ਖੁਰਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/94.pkl
# ਮਹਿੰਦਰਵਰਮਨ ਪਹਿਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/95.pkl
# ਸ਼੍ਰੀ ਗੁਰੂ ਅਮਰਦਾਸ ਜੀ ਦੀ ਬਾਣੀ, ਕਲਾ ਤੇ ਵਿਚਾਰਧਾਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/96.pkl
# ਪੂਰਨ ਸੰਖਿਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/97.pkl
# ਮੈਂਗਨੀਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/98.pkl
# ਹਰੀ ਸਿੰਘ ਨਲੂਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/99.pkl
# ਆਰਨੋਲਡ ਬੈਨੇਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/100.pkl
# ਦਵਿੰਦਰ ਸੈਫ਼ੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/101.pkl
# ਸੰਯੁਕਤ ਰਾਜ ਅਮਰੀਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/102.pkl
# ਅਗਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/103.pkl
# ਵਲਾਦੀਮੀਰ ਲੈਨਿਨ ਪੁਸਤਕ ਸੂਚੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/104.pkl
# ਚੀਰੈਲਿਟੀ (ਭੌਤਿਕ ਵਿਗਿਆਨ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/105.pkl
# ਲੋਬੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/106.pkl
# ਭੂਪਿੰਦਰ ਸਿੰਘ ਸੰਧੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/107.pkl
# ਜੌਨ ਆਫ਼ ਆਰਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/108.pkl
# ਕੜਾ ਰਾਮ ਸਿੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/109.pkl
# ਦਾ ਟਵਾਈਲਾਈਟ ਸਾਗਾ: ਨਿਊ ਮੂਨ (ਫ਼ਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/110.pkl
# ਹਿੰਦੂ ਕਾਲਜ, ਦਿੱਲੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/111.pkl
# ਵੈਕਟਰ ਪੁਟੈਂਸ਼ਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/112.pkl
# ਡੱਚ ਭਾਸ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/113.pkl
# ਮੀਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/114.pkl
# ਪ੍ਰੋਮੀਥੀਅਸ (ਕਾਫ਼ਕਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/115.pkl
# ਜੋਜ਼ਿਫ ਕੋਨਰਾਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/116.pkl
# ਰੂਮੀ ਕੈਥੋਲਿਕ ਕਲੀਸਿਯਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/117.pkl
# ਸਪਿੱਨੌਰ ਫੀਲਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/118.pkl
# ਮਮਤਾ ਬੈਨਰਜੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/119.pkl
# ਢਿੱਲਵਾਂ ਕਲਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/120.pkl
# ਬਿਸਾਓ ਪੈਲੇਸ ਹੋਟਲ, ਜੈਪੁਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/121.pkl
# ਸੀ. ਮਾਰਕੰਡਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/122.pkl
# ਹੁਕਮਦੇਵ ਨਰਾਇਣ ਯਾਦਵ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/123.pkl
# ਆਹਾਰ ਯੋਜਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/124.pkl
# ਦ ਬੀਟਲਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/125.pkl
# ਲਾਂਬੜਾ (ਬਲਾਕ ਹੁਸਿਅਾਰਪੁਰ-1) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/126.pkl
# ਬਾਈਬਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/127.pkl
# ਆਸਟਰੇਲੀਆ ਦਾ ਇਤਿਹਾਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/128.pkl
# ਤਬੀਲਿਸੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/129.pkl
# ਦਿ ਇਕਨੋਮਿਕਸ ਟਾਈਮਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/130.pkl
# ਨਿਆਗਰਾ ਝਰਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/131.pkl
# ਅੰਜੁਲੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/132.pkl
# ਅਹਿਮਦ ਗੁੱਜਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/133.pkl
# ਭੀਮ ਰਾਓ ਅੰਬੇਡਕਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/134.pkl
# ੧੧ ਮਾਰਚ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/135.pkl
# ਵਸੀਲੀ ਬੇਲੋਵ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/136.pkl
# ਤਾਰਾ ਗੁੱਛਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/137.pkl
# ਬਾਡੀ ਬਿਲਡਿੰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/138.pkl
# ਰਾਵੀ ਪਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/139.pkl
# ਨੀਲਮ ਮਾਨ ਸਿੰਘ ਚੌਧਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/140.pkl
# ਲਖਵਿੰਦਰ ਜੌਹਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/141.pkl
# ਡਾ. ਸੁਖਪਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/142.pkl
# ਮਕਲੌਡ ਗੰਜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/143.pkl
# ਸਾਨ ਖ਼ੁਆਨ ਗਿਰਜਾਘਰ (ਸਾਲਵਾਤੀਏਰਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/144.pkl
# ਇਸਮਾਇਲੀ ਮੁਸਲਮਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/145.pkl
# ਸਿੰਹਸ਼ਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/146.pkl
# ਦੇਵੀ ਨਗਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/147.pkl
# ਲਿਵਰ ਸਿਰੋਸਿਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/148.pkl
# ਪਿਤਰੀਮ ਸੋਰੋਕਿਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/149.pkl
# ਗੁਜਰਾਤੀ ਭਾਸ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/150.pkl
# ਅਵਤਾਰ: ਦ ਲਾਸਟ ਏਅਰਬੈਂਡਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/151.pkl
# ਇਲੀਆਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/152.pkl
# 9 ਜੂਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/153.pkl
# ਸੁੰਨੀ ਇਸਲਾਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/154.pkl
# ਭਾਰਤ ਦਾ ਕਾਨੂੰਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/155.pkl
# ਸਾਹਿਰ ਹੁਸ਼ਿਆਰਪੁਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/156.pkl
# ਰੇਖਾ ਗਣਿਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/157.pkl
# ਹੇਠਲੀ ਜਰਮਨ ਭਾਸ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/158.pkl
# ਰੈਂਡਮ ਐਕਸੈਸ ਮੈਮਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/159.pkl
# ਰੀਮਾ ਨਾਨਾਵਤੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/160.pkl
# ਕੈਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/161.pkl
# ਅਲਦੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/162.pkl
# ਖੁਦਾਈ ਖਿਦਮਤਗਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/163.pkl
# ਇਸਾਮੂ ਅਕਾਸਾਕੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/164.pkl
# ਠੁੱਲੀਵਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/165.pkl
# ਵਿਸ਼ਵ ਵਿਰਾਸਤ ਟਿਕਾਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/166.pkl
# ਹਸਨਪੁਰ (ਘਨੌਰ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/167.pkl
# ਗ੍ਰੈਗੋਰੀਅਨ ਕਲੰਡਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/168.pkl
# ਮਰਸਿਨ ਸੂਬਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/169.pkl
# 1747 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/170.pkl
# ਖੁੰਭ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/171.pkl
# ਪਾਕਿਸਤਾਨੀ ਟੀਵੀ ਡਰਾਮੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/172.pkl
# ਉਚਾਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/173.pkl
# ਈਦ-ਉਲ-ਜ਼ੁਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/174.pkl
# ਕੌਸਾ ਸੂਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/175.pkl
# ਰੋਡੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/176.pkl
# ਬਿਜਨੌਰ ਲੋਕ ਸਭਾ ਹਲਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/177.pkl
# ਮੰਗਤੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/178.pkl
# ਬਾਲਟੀਮੋਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/179.pkl
# ਗੇੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/180.pkl
# 483 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/181.pkl
# ਗੁਰੂਸਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/182.pkl
# ਵਾਈ (ਅੰਗਰੇਜ਼ੀ ਅੱਖਰ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/183.pkl
# ਭਿਖਾਰੀ ਠਾਕੁਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/184.pkl
# ਤੋਚੀ ਰੈਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/185.pkl
# ਕਾਬੁਲ ਸ਼ਾਹੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/186.pkl
# ਨੈਸ਼ਨਲ ਹੇਰਾਲਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/187.pkl
# ਟੌਮ ਜੋਨਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/188.pkl
# ਰਘੁਵੀਰ ਯਾਦਵ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/189.pkl
# ਮਕਸੂਦ ਸਾਕਿਬ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/190.pkl
# ਭੂਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/191.pkl
# ਉਸਾਰੀ ਕਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/192.pkl
# ਬੋਨੀ ਕਪੂਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/193.pkl
# ਗਣੇਸ਼ ਚਤੁਰਥੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/194.pkl
# ਪਰਮੇਸ਼ਵਰਵਰਮਨ ਦੂਜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/195.pkl
# ਡਗਾਣਾ ਕਲਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/196.pkl
# ੧੮ ਮਾਰਚ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/197.pkl
# ਬਰਗੰਡੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/198.pkl
# ਮੰਜੂਨਾਥ (ਫਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/199.pkl
# ਰਮਜ਼ਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/200.pkl
# ਜੇਨਬੁੱਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/201.pkl
# ਡਾ. ਡਰੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/202.pkl
# ਅਰਕੀ ਦਾ ਕਿਲ੍ਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/203.pkl
# ਉਐਸਕਾ ਵੱਡਾ ਗਿਰਜਾਘਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/204.pkl
# ਪੰਜਾਬ ਦਾ ਲੋਕ ਸੰਗੀਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/205.pkl
# ਪ੍ਰੀ-ਏਕਲਪਸੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/206.pkl
# ਸੁਭਾਸ਼ ਪਾਲੇਕਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/207.pkl
# ਪਵਿੱਤਰ ਪਿਬੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/208.pkl
# ਉੱਧਵ ਕਿਆਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/209.pkl
# ਸਲਮਾਨ ਬੱਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/210.pkl
# ਬਿਜਲੀ-ਨਿਖੇੜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/211.pkl
# ਹੰਸਾ ਸਿੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/212.pkl
# ਵਰਤ ਕਥਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/213.pkl
# ਅਬੂਤਾਲਿਬ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/214.pkl
# ਲੈਲਾ ਸੁਰਤਸੁਮੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/215.pkl
# ਰਿਲੇਟੀਵਿਸਟਿਕ ਕੁਆਂਟਮ ਮਕੈਨਿਕਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/216.pkl
# ਭਰਾਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/217.pkl
# ਰਾਲਫ ਵਾਲਡੋ ਐਮਰਸਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/218.pkl
# ਗੇਹਲੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/219.pkl
# ਵਾਇਲਟ ਐਲਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/220.pkl
# ਆਨਾਦਿ ਫਾਊਂਡੇਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/221.pkl
# ਗੀਗਨਵਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/222.pkl
# ਹੰਸਰਾਜ ਕਾਲਜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/223.pkl
# ਸੁਦਰਸ਼ਨ ਪਟਨਾਇਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/224.pkl
# ਸਰੋਜਿਨੀ ਸਾਹੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/225.pkl
# ਛੋਟੀ ਮਾਤਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/226.pkl
# ਕੋਟਕਪੂਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/227.pkl
# ਬਾਰਬਰਾ ਨਵਾਬਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/228.pkl
# ਕਲਾਲ ਮਾਜ਼ਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/229.pkl
# ਪੰਜਾਬ ਯੂਨੀਵਰਸਿਟੀ, ਚੰਡੀਗੜ੍ਹ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/230.pkl
# ਨੌਰੋਤੀ ਦੇਵੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/231.pkl
# ਜੇਠੂਕੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/232.pkl
# ਮੋਜ਼ੈਂਬੀਕ ਨਹਿਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/233.pkl
# ਕੁਆਂਟਮ ਸੂਚਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/234.pkl
# ਵਿਸ਼ਵ ਵਾਤਾਵਰਣ ਦਿਵਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/235.pkl
# ਗੈਰੀ ਪਲੇਅਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/236.pkl
# ਬਰਲਿਨ ਦੀ ਕੰਧ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/237.pkl
# ਪਸਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/238.pkl
# ਵਿਕੀਪੀਡੀਆ:ਵਿਗਿਆਨਿਕ ਸ਼ਬਦਾਵਲੀ/ਰੈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/239.pkl
# ਭਾਦੋਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/240.pkl
# ਕਾਸਤਾਮੋਨੋ ਸੂਬਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/241.pkl
# 1808 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/242.pkl
# ਇਸਲਾਮ ਦੇ ਪਵਿੱਤਰ ਗ੍ਰੰਥ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/243.pkl
# ਪੁਰਾਤਨ ਯੂਨਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/244.pkl
# ਗੁਰੂ ਕੇ ਬਾਗ਼ ਦਾ ਮੋਰਚਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/245.pkl
# ਓ ਹੈਨਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/246.pkl
# ਸਿੱਖੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/247.pkl
# ਲਾਲਟੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/248.pkl
# ਮਲਕੀਤ ਸਿੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/249.pkl
# ਘੁੱਲੂ ਮਾਜਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/250.pkl
# ਅਲਬਾਸੇਤੇ ਵੱਡਾ ਗਿਰਜਾਘਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/251.pkl
# 2015 ਬੱਲਭਗੜ੍ਹ ਦੰਗੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/252.pkl
# ਇਰੈਡੀਏਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/253.pkl
# ਜਲਵੇੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/254.pkl
# ੩੨੯ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/255.pkl
# ਓਮ ਪੁਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/256.pkl
# ਪੰਜਾਬੀ ਜਾਗਰਣ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/257.pkl
# ਅਤਿਸੂਖਮ ਲਹਿਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/258.pkl
# ਮੁਗ਼ਲ ਬਾਦਸ਼ਾਹਾਂ ਦੀ ਸੂਚੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/259.pkl
# ਨੱਥੂਪੁਰ (ਬਲਾਕ ਟਾਂਡਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/260.pkl
# ਬ੍ਰਹਿਮੰਡੀ ਤਰੰਗ ਫੰਕਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/261.pkl
# 3 ਡੀ ਅਲਟਰਾਸਾਉਂਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/262.pkl
# ਵਿਸ਼ਵ ਕੁਸ਼ਤੀ ਚੈਂਪੀਅਨਸ਼ਿਪ 2006 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/263.pkl
# ਚੁਰਾਚਾਂਦਪੁਰ ਜ਼ਿਲ੍ਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/264.pkl
# ਟੌਟਨਹਮ ਹੌਟਸਪਰ ਫੁੱਟਬਾਲ ਕਲੱਬ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/265.pkl
# ਭਾਰਤੀ ਇਲਾਕਾਈ ਫ਼ੌਜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/266.pkl
# ਗੌਰੀ ਖ਼ਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/267.pkl
# ਨਵ ਇੰਦਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/268.pkl
# ਕਾਰਬਨੀ ਰਸਾਇਣ ਵਿਗਿਆਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/269.pkl
# ਕੋਹ ਕਾਫ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/270.pkl
# ਘੁੱਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/271.pkl
# ਲੂਈ ਅਲਥੂਜ਼ਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/272.pkl
# ਭਾਸ਼ਾ ਪਰਿਵਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/273.pkl
# 1 ਫ਼ਰਵਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/274.pkl
# ਪ੍ਰਿਥੀਪਾਲ ਸਿੰਘ ਰੰਧਾਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/275.pkl
# ਉੱਤਰੀ ਸਮੁੰਦਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/276.pkl
# ਵਨ ਡਾਇਰੈਕਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/277.pkl
# ਜੈਕ ਲੰਡਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/278.pkl
# ਬਿਮਲ ਮਿੱਤਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/279.pkl
# ਰੱਤਾ ਖੇੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/280.pkl
# ਰਾਜ-ਸੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/281.pkl
# ਜਾਨ ਬੋਰਥਵਿਕ ਗਿਲਕਰਿਸਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/282.pkl
# 1800 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/283.pkl
# ਮੁਗਲ ਸਰਾਂ, ਦੋਰਾਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/284.pkl
# ਫਾਟਕ:ਗਣਿਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/285.pkl
# ਗੁਰੂ ਤੇਗ ਬਹਾਦਰ ਜੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/286.pkl
# ਭਗਵਾਨ ਸਿੰਘ ਦਾਮਲੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/287.pkl
# ਲਿਨਅਕਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/288.pkl
# ਸ਼ੁਭਾਂਗੀ ਅਤਰੇ ਪੂਰੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/289.pkl
# ੨੩ ਫ਼ਰਵਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/290.pkl
# ਆਲੀਯਾ ਰਸ਼ੀਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/291.pkl
# ਨਿਕਿਤਾ ਡੇਨਿਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/292.pkl
# ਆਇਡਾਹੋ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/293.pkl
# ਇਥੋਪੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/294.pkl
# ਸ਼ਿਕਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/295.pkl
# ਯੂਰਪੀ ਪੁਲਾੜ ਏਜੰਸੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/296.pkl
# ਮਹੰਮਦ ਹਾਮਿਦ ਅੰਸਾਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/297.pkl
# ਵੂਪੀ ਗੋਲਡਬਰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/298.pkl
# ਸਪਿੱਨੌਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/299.pkl
# ਹਮਨਸ਼ੀਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/300.pkl
# ਆਪਰੇਟਿੰਗ ਸਿਸਟਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/301.pkl
# ਅਜਰਬੈਜਾਨ ਗਣਰਾਜ ਦਾ ਰਾਸ਼ਟਰਗਾਣ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/302.pkl
# ਅਦਨਾਨ ਖ਼ਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/303.pkl
# ਇਵੈਂਟ ਹੌਰਿਜ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/304.pkl
# ਹਥੌੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/305.pkl
# ਯੂਸਫਪੁਰ ਦਾਰੇਵਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/306.pkl
# ਮਲਾਵੀ ਝੀਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/307.pkl
# ਪੂਨੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/308.pkl
# ਪਲੀਮਥ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/309.pkl
# ਰਿਤੁ ਬਰਮੇਚਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/310.pkl
# ਗੁਰਦਾਸਪੁਰ ਜ਼ਿਲ੍ਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/311.pkl
# ਵੈਨਿਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/312.pkl
# ਛਬੀਲਪੁਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/313.pkl
# ਅਲੀ ਬਾਬਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/314.pkl
# ਪੂਰਬੀ ਜਰਮਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/315.pkl
# 10 ਫ਼ਰਵਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/316.pkl
# ਚੱਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/317.pkl
# ਯਾ ਆਸਾਂਤੇਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/318.pkl
# ਬਰਫ਼-ਤੋਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/319.pkl
# ਮਨਜ਼ੂਰ ਏਜਾਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/320.pkl
# ਮਰਦਾਂ ਦਾ ਪਹਿਰਾਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/321.pkl
# ਸਾਂਤਾ ਕਰੂਸ ਗਿਰਜਾਘਰ (ਕਾਂਗਾਸ ਦੇ ਓਨੀਸ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/322.pkl
# ਗੌਫ਼ਰੀਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/323.pkl
# ਅਲਹੌਰਾਂ ਖੁਰਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/324.pkl
# ਵੈਕਟਰ (ਰੇਖਾਗਣਿਤ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/325.pkl
# ਸ਼ਫੀ ਮੁਹੰਮਦ ਬਰਫਾਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/326.pkl
# ਬਹਿਰੂਨ ਹਰਿਅਾਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/327.pkl
# ਸੱਪ ਦਾ ਡੱਸਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/328.pkl
# ਉਲਟਪਦਾਰਥ ਦੀ ਗਰੈਵੀਟੇਸ਼ਨਲ ਪਰਸਪਰ ਕ੍ਰਿਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/329.pkl
# ਭੌਤਿਕਵਾਦ ਅਤੇ ਅਨੁਭਵਸਿੱਧ-ਆਲੋਚਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/330.pkl
# ੧ (ਸੰਖਿਆ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/331.pkl
# ਅਹਲ ਅਲਬੈਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/332.pkl
# ਜਗਰਾਵਾਂ ਦਾ ਰੋਸ਼ਨੀ ਮੇਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/333.pkl
# ਐੱਮ. ਕੇ. ਰੈਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/334.pkl
# ਸਪਿੱਨ-c ਬਣਤਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/335.pkl
# 357 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/336.pkl
# ਜੋਹਾਨਿਸਬਰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/337.pkl
# ਭਗਵਾਨਪੁਰ ਹੀਂਗਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/338.pkl
# ਮਨਸੂਰਪੁਰ (ਬਲਾਕ ਫਿਲੌਰ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/339.pkl
# ਛਤਰਪਤੀ ਸ਼ਿਵਾਜੀ ਅੰਤਰਰਾਸ਼ਟਰੀ ਹਵਾਈ ਅੱਡਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/340.pkl
# ਮੈਟਰੋਪੋਲੀਟਨ ਏਰੀਆ ਨੈੱਟਵਰਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/341.pkl
# ਸਤਰੰਗੀ ਸਸੁਰਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/342.pkl
# ਸ਼ੌਕਤ ਉਸਮਾਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/343.pkl
# 5 ਅਗਸਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/344.pkl
# 1503 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/345.pkl
# 1521 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/346.pkl
# ਪੰਜਾਬ ਰਾਜ ਦੀਆਂ ਵਿਕਾਸ ਯੋਜਨਾਵਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/347.pkl
# ਡਮਰੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/348.pkl
# ਧੀਆਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/349.pkl
# ਬਾਇਥਾ ਗਿਰਜਾਘਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/350.pkl
# ਚਰਿੱਤਰ ਘਾਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/351.pkl
# ਦਿਉਣ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/352.pkl
# ਸੇਂਟ ਜੇਕਬ-ਪਾਰਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/353.pkl
# ਘੁਮਿਆਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/354.pkl
# ਅਮਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/355.pkl
# ਅੱਲਾਹ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/356.pkl
# ਬਰਫ਼ਾਨੀ ਰੋੜ੍ਹ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/357.pkl
# ਬੇਰੂਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/358.pkl
# ਨਾੜੀ ਗਰੰਥੀ ਪੁਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/359.pkl
# ਅਯੂਬ ਖਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/360.pkl
# ਰਘੂ ਰਾਏ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/361.pkl
# 7 ਮਾਰਚ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/362.pkl
# ਮੀਆਂ ਇਫ਼ਤਿਖ਼ਾਰਉੱਦੀਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/363.pkl
# ਥਿਰੁਸ਼ ਕਾਮਿਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/364.pkl
# ਯਮਕੇਸ਼ਵਰ ਵਿਧਾਨ ਸਭਾ ਹਲਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/365.pkl
# ਧੁਨੀ ਸੰਪਰਦਾਇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/366.pkl
# 1838 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/367.pkl
# ਗਿੱਲ, ਲੁਧਿਆਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/368.pkl
# ਅੰਗੋਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/369.pkl
# ਉੱਚਾ (ਜਲੰਧਰ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/370.pkl
# ਕੰਨੀਆਂ ਖੁਰਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/371.pkl
# ਓਮੁਸਾਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/372.pkl
# ਤਾਸ਼ਕੰਤ ਐਲਾਨਨਾਮਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/373.pkl
# ਨੰਦਗੜ੍ਹ (ਜ਼ਿਲ੍ਹਾ ਮਾਨਸਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/374.pkl
# ਸਹਿਮ (ਪਿੰਡ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/375.pkl
# ﻿ਸ਼ਾਹ ਗ਼ੁਲਾਮ ਅਲੀ ਦੇਹਲਵੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/376.pkl
# ਦਾ ਪਾਰਕ ਵਿਸ਼ਾਖਾਪਟਨਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/377.pkl
# ਠੰਢੀ ਜੰਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/378.pkl
# ਚਪੜੌਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/379.pkl
# ਗੁਰਮੁਖੀ ਲਿਪੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/380.pkl
# ਦਿੱਲੀ ਪੋਇਟਰੀ ਫ਼ੈਸਟੀਵਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/381.pkl
# ਉਮਾ ਚੌਧਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/382.pkl
# ਪੌਲੀ ਇਕੁਏਸ਼ਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/383.pkl
# ਰਿਪਬਲਿਕ (ਪਲੈਟੋ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/384.pkl
# ਕੂਕਾ ਲਹਿਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/385.pkl
# ਬਲਕਾਰ ਸਿੱਧੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/386.pkl
# ਮਰੀਅਮ ਮਿਰਜ਼ਾਖ਼ਾਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/387.pkl
# ਮੋਤੀ ਬਾਗ਼ ਮਹਿਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/388.pkl
# ਐੱਚ.ਡੀ.ਆਈ-ਆਰੇਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/389.pkl
# ਵਿਕਤੋਰ ਊਗੋ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/390.pkl
# ਪਾਸਕਲ ਬਰੈਸਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/391.pkl
# 111 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/392.pkl
# ਬਹਾਵਲਪੁਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/393.pkl
# ਰਾਜਗੜ੍ਹ (ਘਨੌਰ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/394.pkl
# ਏ ਫ਼ੇਅਰਵੈੱਲ ਟੂ ਆਰਮਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/395.pkl
# ਅੱਲੂਵਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/396.pkl
# ਅੱਖ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/397.pkl
# ਬਾਰਬਰਾ ਹਰਸ਼ੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/398.pkl
# ਜੌੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/399.pkl
# ਹਤਿਆਰੇ (ਹੈਮਿੰਗਵੇ ਦੀ ਨਿੱਕੀ ਕਹਾਣੀ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/400.pkl
# ਚੋਟੀਆਂ (ਮਾਨਸਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/401.pkl
# ਦਮਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/402.pkl
# ੨੮ ਫ਼ਰਵਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/403.pkl
# ਨਿਵੇਦਿਤਾ ਮੇਨਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/404.pkl
# ਮਾਹੋਰਾਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/405.pkl
# ਹਰਪਾਲ ਟਿਵਾਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/406.pkl
# 1968 ਓਲੰਪਿਕ ਖੇਡਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/407.pkl
# ਅਲਕਾਲਾ ਦੇ ਏਨਾਰਿਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/408.pkl
# ਕੁਮੈਲ ਨੰਜੀਆਨੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/409.pkl
# ਤੁਰਕੀ (ਪੰਛੀ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/410.pkl
# ਪੰਜਾਬੀ ਜੰਗਨਾਮਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/411.pkl
# ਲੈੱਨਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/412.pkl
# ਉਟਾਲਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/413.pkl
# ...
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5442.pkl
# ਯਿਨ ਅਤੇ ਯਾਂਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5443.pkl
# ਭਾਈ ਮਹਾਰਾਜ ਸਿੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5444.pkl
# ਨਖ਼ਲਿਸਤਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5445.pkl
# ਮਾਕਸ ਪਲਾਂਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5446.pkl
# ਮੰਗੂ ਰਾਮ ਮੁਗੋਵਾਲੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5447.pkl
# ਯੂਨੀਟੈੱਕ ਇੰਸਟੀਚਿਊਟ ਆਫ਼ ਟੈਕਨਾਲੋਜੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5448.pkl
# ਈਸਾ ਮਸੀਹ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5449.pkl
# ਸ਼ਿਕਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5450.pkl
# ਗੁਰਦੁਆਰਾ ਸੰਤੋਖਸਰ ਸਾਹਿਬ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5451.pkl
# ਹੈਂਕ ਐਰਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5452.pkl
# ਜੇਨੁਰੀ ਸਚੋਦੋਲਸਕੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5453.pkl
# ਜਾਕੋਮੋ ਕਾਸਾਨੋਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5454.pkl
# ਖ਼ੁਦਕੁਸ਼ੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5455.pkl
# ਅਸਤਾਦ ਦੇਬੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5456.pkl
# ਜੁਨੂੰਨ (1978 ਫ਼ਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5457.pkl
# ਵਾਰਤਾ ਟਰਸਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5458.pkl
# ਸਮੁਦਰਗੁਪਤ ਦੀਆਂ ਜਿੱਤਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5459.pkl
# ਧੂੜਕੋਟ ਰਣਸੀਂਹ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5460.pkl
# ਉੱਤਮ ਖੋਬਰਾਗੜੇ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5461.pkl
# ਅਸਤਿਤਵ ਸਾਰ ਤੋਂ ਪਹਿਲਾਂ ਹੈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5462.pkl
# ਪਸਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5463.pkl
# ਵਿਸ਼ੇਸ਼ ਸਾਪੇਖਤਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5464.pkl
# ਕੈਲੀਫ਼ੋਰਨੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5465.pkl
# ਸੇਰਗੇਈ ਬੋਂਦਾਰਚੁਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5466.pkl
# ਕਾਂਸਤਾਂਤਨੋਪਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5467.pkl
# ਚੰਗ ਹਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5468.pkl
# ਇਜ਼ਰਾਇਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5469.pkl
# ਛਾਂਙਸ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5470.pkl
# ਓਮੀਕ੍ਰੋਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5471.pkl
# ਬਲਦੇਵ ਸਿੰਘ ਧਾਲੀਵਾਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5472.pkl
# ਸ਼ਿਕਾਰਖ਼ੋਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5473.pkl
# ਰਿਲੇਟੀਵਿਸਟਿਕ ਕੁਆਂਟਮ ਮਕੈਨਿਕਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5474.pkl
# ਬੰਬੂਕਾਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5475.pkl
# ਆਮਾਰ ਸੋਨਾਰ ਬੰਗਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5476.pkl
# 1864 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5477.pkl
# ਤਰਸੇਮ (ਕਵੀ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5478.pkl
# ਮਹਾਂ ਧਮਾਕਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5479.pkl
# ਰਜਿੰਦਰ ਸਿੰਘ ਬੱਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5480.pkl
# ਯਾਕ ਦੇਰੀਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5481.pkl
# ਜੌਨ ਮੈਕਨਰੋ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5482.pkl
# ਮਾਂਡਵੀ ਨਦੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5483.pkl
# ਡੀ ਬ੍ਰੋਗਲਾਇ-ਬੋਹਮ ਥਿਊਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5484.pkl
# ਤਕਸੀਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5485.pkl
# ਦੂਸਰੇ ਵਿਸ਼ਵ ਯੁੱਧ ਵਿੱਚ ਭਾਰਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5486.pkl
# ਐਨਰੀਕੋ ਫ਼ੇਅਰਮੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5487.pkl
# ਝਲਕਾਰੀ ਬਾਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5488.pkl
# 4 ਜੂਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5489.pkl
# ਕਾਰਲ ਵਰਨਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5490.pkl
# ਦੱਖਣੀ ਅਰਧਗੋਲ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5491.pkl
# ਮੋਹਿੰਦਰ ਅਮਰਨਾਥ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5492.pkl
# ਬੱਗੇਆਣਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5493.pkl
# ਅਨਿਲਦਾ ਥਾਮਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5494.pkl
# ਜਵਾਹਰ ਲਾਲ ਨਹਿਰੂ ਯੂਨੀਵਰਸਿਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5495.pkl
# ਜੱਦਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5496.pkl
# ਕੁਲਬੀਰ ਸਿੰਘ ਕਾਂਗ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5497.pkl
# ਸੂਜ਼ੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5498.pkl
# ਕਰਵਾ ਚੌਥ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5499.pkl
# ਕੁਬਤੀ ਲੋਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5500.pkl
# ਕਾਲੀਆਂ ਪਹਾੜੀਆਂ (ਬਲੈਕ ਹਿਲਜ਼) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5501.pkl
# ਤਿੰਨ ਭੈਣਾਂ (ਨਾਟਕ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5502.pkl
# ਮੀਰਾਂਪੁਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5503.pkl
# ਬਹਿਰੂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5504.pkl
# ਵਿਸ਼ਨੂੰ ਪ੍ਰਭਾਕਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5505.pkl
# ਅਲੈਗਜ਼ੈਵਕਾ, ਬੈਲਗੋਰੋਡ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5506.pkl
# ਮਾਇਕਰੋਫੋਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5507.pkl
# ਸੰਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5508.pkl
# ਚੇਨਈ ਵਿੱਚ ਐੱਲਜੀਬੀਟੀ ਸੱਭਿਆਚਾਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5509.pkl
# 21 ਜਨਵਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5510.pkl
# ਰੁੱਖ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5511.pkl
# ਹਿਮਾਨੀ ਚਾਵਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5512.pkl
# ਇਸਾਈ ਧਰਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5513.pkl
# ਛੜਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5514.pkl
# ਮਹਾਂਨਗਰ (ਫ਼ਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5515.pkl
# ਅੰਨਾ ਕਾਰੇਨੀਨਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5516.pkl
# ਕਲੈਸ਼ ਰੋਆਇਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5517.pkl
# ਲੋਧੀ ਚੱਕ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5518.pkl
# ਸਟੇਡੀਅਮ ਮਾਨਚੈਸਟਰ ਸ਼ਹਿਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5519.pkl
# ਪੰਜਾਬ ਖੇਤੀਬਾੜੀ ਯੂਨੀਵਰਸਿਟੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5520.pkl
# ਮੁਗਲਾ ਸੂਬਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5521.pkl
# ਰਾਮਦੇਵ ਅਰਵਿਦੁ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5522.pkl
# ਵਰਜੀਨੀਆ ਵੁਲਫ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5523.pkl
# ਹਾਇਗਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5524.pkl
# ਬੌਂਦਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5525.pkl
# ਬੂਟਾ ਸਿੰਘ ਸ਼ਾਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5526.pkl
# ਵਿਕੀਪੀਡੀਆ:ਵਿਗਿਆਨਿਕ ਸ਼ਬਦਾਵਲੀ/ਪ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5527.pkl
# ਐੱਫ਼. ਸੀ. ਲੋਕੋਮੋਟਿਵ ਮਾਸਕੋ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5528.pkl
# ਭਾਰਤੀ ਮਹਿਲਾ ਕ੍ਰਿਕਟ ਟੀਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5529.pkl
# ਭਾਸ਼ਾ ਜਾਵਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5530.pkl
# ਸਨਾਇਪਰ (1993 ਫ਼ਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5531.pkl
# ਮੁਰਦਾ ਸਮੁੰਦਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5532.pkl
# ਰਾਜਸਥਾਨ ਦੀ ਯੂਨੀਵਰਸਿਟੀ ਲਾਇਬ੍ਰੇਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5533.pkl
# ਪੀਜ਼ਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5534.pkl
# ਤਾਰਿਕ ਹਮੀਦ ਕਾਰਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5535.pkl
# ਛੋਟਾ ਜਲ ਬਟੇਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5536.pkl
# ਵੰਡ (ਨਿੱਕੀ ਫ਼ਿਲਮ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5537.pkl
# ਅਜਨੌਦਾ ਕਲਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5538.pkl
# ਸਲੇਮਪੁਰ ਜੱਟਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5539.pkl
# ਯੂਨਾਨੀ ਇਲਾਜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5540.pkl
# ੧੨੦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5541.pkl
# ਪ੍ਰੀਤੀ ਡਿਮਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5542.pkl
# ਤਿੱਤਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5543.pkl
# ਚਿਹਨ-ਵਿਗਿਆਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5544.pkl
# ਭਾਰਤੀ ਕ੍ਰਿਕਟ ਟੀਮ ਦਾ ਆਸਟਰੇਲੀਆ ਦੌਰਾ 2015-16 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5545.pkl
# ਰਾਣੀ ਲਕਸ਼ਮੀਬਾਈ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5546.pkl
# ਕੇਟ ਵਿੰਸਲੇਟ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5547.pkl
# ਤਖਾਣਵੱਧ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5548.pkl
# ਹਿਗਜ਼ ਬੋਸੌਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5549.pkl
# ਸੰਗੀਤ ਇਲਾਜ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5550.pkl
# ਕਠੂਆ ਬਲਾਤਕਾਰ ਕੇਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5551.pkl
# ਇਰੀਡੀਅਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5552.pkl
# ਈਸਪ ਦੀਆਂ ਕਹਾਣੀਆਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5553.pkl
# ਪ੍ਰਿਯਾਦਰਸ਼ਨੀ ਰਾਜੇ ਸਿੰਧੀਆ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5554.pkl
# 336 - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5555.pkl
# ਏਚ ਟੀ ਸੀ ਵਾਈਵ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5556.pkl
# ਜੋਗਾ ਨੰਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5557.pkl
# ਭਾਰਤੀ ਰਾਸ਼ਟਰੀ ਕਾਂਗਰਸ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5558.pkl
# ਮਹਾਜਨਪਦ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5559.pkl
# ਸੁਰਜੀਤ ਪਾਤਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5560.pkl
# ਟਾਮਸ﻿ ਮਾਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5561.pkl
# ਬਾਦਲ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5562.pkl
# ਪੂਰਨ ਚੰਦ ਜੋਸ਼ੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5563.pkl
# ਕੂਸੋਵੇ ਜ਼ਿਲਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5564.pkl
# ਲੀਸਾ ਈ ਬਲੂਮ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5565.pkl
# ਅਧਿਆਤਮਕ ਵਾਰਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5566.pkl
# ਤਾਹਿਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5567.pkl
# ਬਿਜਲਈ ਚਿੰਨ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5568.pkl
# ਪਰਦੁੱਮਣ ਸਿੰਘ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5569.pkl
# ਕਾਹਲਵਾਂ (ਬਲਾਕ ਟਾਂਡਾ) - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5570.pkl
# ਏਕਤਾ ਦਾ ਬੁੱਤ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5571.pkl
# ਰਿਹਾਣਾ ਜੱਟਾਂ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5572.pkl
# ਮਹਾਤਮਾ ਗਾਂਧੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5573.pkl
# ਜਗੀਰਦਾਰੀ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5574.pkl
# ਪੇਨੇਲੋਪੇ ਕਰੂਜ਼ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5575.pkl
# ਭਾਰਤ ਵਿੱਚ ਮਜ਼ਦੂਰ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5576.pkl
# ਹਜਾਰਾ ਸਿੰਘ ਰਮਤਾ - ਵਿਕੀਪੀਡੀਆ, ਇਕ ਅਜ਼ਾਦ ਵਿਸ਼ਵਗਿਆਨਕੋਸ਼
# Saved /media/gaurav/Goru/datasets/PanjabiWikipediaArticles/5577.pkl

# %%
with open('/media/gaurav/Goru/datasets/PanjabiWikipediaArticles/12.pkl', 'rb') as f:
    s = pickle.load(f)

# %%
s
# Out:
# 'ਡਾਂਸ ਇੱਕ ਅਜਿਹੀ ਕਲਾ ਹੈ ਜਿਸ ਵਿੱਚ ਸ਼ਰੀਰਕ ਹਰਕਤਾਂ ਨਾਲ ਮਨ ਦੇ ਭਾਵਾਂ ਦੀ ਅਭਿਵਿਅਕਤੀ ਹੁੰਦੀ ਹੈ। ਆਮ ਤੌਰ ਤੇ ਡਾਂਸ, ਸੰਗੀਤ ਜਾਂ ਤਾਲ ਉੱਤੇ ਕੀਤਾ ਜਾਂਦਾ ਹੈ ਜਿਸ ਵਿੱਚ ਸ਼ਰੀਰ ਦੇ ਅੰਗਾਂ ਅਤੇ ਪੈਰਾਂ ਦੀ ਹਰਕਤਾਂ ਦੀ ਵਰਤੋਂ ਨਿਸ਼ਚਿਤ ਕੀਤੀ ਜਾਂਦੀ ਹੈ।\nਡਾਂਸ ਦਾ ਆਰੰਭ ਹੋਣ ਦੇ ਪੁਰਾਤਤਵ ਸਬੂਤ ਮਿਲਦੇ ਹਨ ਜਿਹਨਾਂ ਅਨੁਸਾਰ ਭਾਰਤ ਵਿੱਚ ਭੀਮਬੇਟਕਾ ਦੀਆਂ ਚਟਾਨਾਂ ਉੱਤੇ 9,000 ਸਾਲ ਪੁਰਾਣੇ ਚਿੱਤਰ ਮਿਲਦੇ ਹਨ ਅਤੇ 3300 ਈ. ਪੂਰਵ ਮਿਸਰ ਦੇ ਮਕਬਰੇ ਦੀ ਚਿਤਰਕਾਰੀ ਵੀ ਨ੍ਰਿਤ ਤਸਵੀਰਾਂ ਨੂੰ ਪੇਸ਼ ਕਰਦੀ ਹੈ।ਭਾਸ਼ਾ ਦੇ ਹੋਂਦ ਵਿੱਚ ਆਉਣ ਤੋਂ ਪਹਿਲਾਂ ਡਾਂਸ ਹੀ ਇੱਕ ਮਾਤਰ ਅਜਿਹਾ ਤਰੀਕਾ ਸੀ ਜੋ ਕਹਾਣੀਆਂ ਨੂੰ ਪੀੜੀ-ਦਰ-ਪੀੜੀ ਅੱਗੇ ਤੋਰਦਾ ਸੀ। \nਲਾਤੀਨੀ ਡਾਂਸ ਦਾ ਪ੍ਰਮਾਣ ਪਲੈਟੋ,ਅਰਸਤੂ,ਪਲੂਟਾਰਕ ਅਤੇ ਲੁਸੀਅਨ ਦੁਆਰਾ ਦਿੱਤਾ ਗਿਆ ਹੈ। \nਬਾਈਬਲ ਅਤੇ ਤਲਮੂਦ ਵਿੱਚ ਵੀ ਅਜਿਹੀਆਂ ਮਹੱਤਵਪੂਰਨ ਘਟਨਾਵਾਂ ਦਾ ਜ਼ਿਕਰ ਮਿਲਦਾ ਹੈ ਜੋ ਨ੍ਰਿਤ ਨਾਲ ਸਬੰਧਿਤ ਹਨ ਅਤੇ ਵੱਖਰੀ-ਵੱਖਰੀ 30 ਤੋਂ ਵੱਧ ਡਾਂਸ ਨਿਯਮਾਂ ਦਾ ਵਰਣਨ ਕੀਤਾ ਗਿਆ ਹੈ। \nਨ੍ਰਿਤ ਦਾ ਪ੍ਰਾਚੀਨ ਗ੍ਰੰਥ ਭਾਰਤ ਮੁਨੀ ਦਾ ਨਾਟਯ-ਸ਼ਾਸਤਰ ਹੈ। ਨਾਟਕ ਵਿੱਚ ਨ੍ਰਿਤ ਨਾਟਕ ਸਭ ਤੋਂ ਅਹਿਮ ਭੂਮਿਕਾ ਨਿਭਾਉਂਦੇ ਹਨ ਜੋ ਭਾਰਤੀ ਸਭਿਆਚਾਰ ਦਾ ਮਹੱਤਵਪੂਰਨ ਅੰਗ ਹੈ। ਡਾਂਸ ਨੂੰ ਚਾਰ ਕਿਸਮਾਂ - ਧਰਮ-ਨਿਰਪੱਖ,ਧਾਰਮਿਕ ,ਭਾਵਮਈ ਅਤੇ ਵਿਆਖਿਆਮੂਲਕ ਅਤੇ ਇਹ ਕਿਸਮਾਂ ਅਤੇ ਚਾਰ ਖੇਤਰੀ ਵਿੱਚ ਵੰਡਿਆ ਗਿਆ।\nਬਹੁਤ ਸਾਰੇ ਸਮਕਾਲੀ ਡਾਂਸ ਰੂਪਾਂ ਦਾ ਪਤਾ ਇਤਿਹਾਸਕ,ਪਰੰਪਰਾਗਤ,ਰਸਮੀ ਅਤੇ ਰਸਮੀ ਨਾਚਾਂ ਨਾਲ ਲਗਾਇਆ ਜਾ ਸਕਦਾ ਹੈ।\nਪੇਸ਼ਾਵਰ ਨ੍ਰਿਤਕਾਰ ਆਮ ਤੌਰ ਤੇ ਠੇਕੇ ਉੱਤੇ ਜਾਂ ਖ਼ਾਸ ਪ੍ਰਦਰਸ਼ਨ ਜਾਂ ਕਲਾਕਿਰਤੀ ਲਈ ਕੰਮ ਕਰਦੇ ਹਨ। ਇੱਕ ਪੇਸ਼ਾਵਰ ਡਾਂਸਰ ਦੀ ਜ਼ਿੰਦਗੀ ਦੀ ਕਾਰਜੀ ਹਾਲਤ ਲਗਾਤਾਰ ਬਦਲਦੀ ਹੈ ਜਿਸਦਾ ਕਾਰਨ ਨਿੱਗਰ ਪ੍ਰਤੀਯੋਗੀ ਅਤੇ ਘੱਟ ਤਨਖਾਹ ਹੈ।\nਡਾਂਸ ਮਾਸਟਰ ਖ਼ਾਸ ਤੌਰ ਉੱਤੇ ਡਾਂਸ ਪ੍ਰਦਸ਼ਨਾਂ ਜਾਂ ਮੁਕਾਬਲੇ ਲਈ ਖੜੇ ਪ੍ਰਤਿਯੋਗਿਆਂ ਕੋਚਿੰਗ ਦਿੰਦੇ ਹਨ। ਉਹਨਾਂ ਨੂੰ ਉਹਨਾਂ ਡਾਂਸ ਪ੍ਰਦਰਸ਼ਨਾਂ ਦਾ ਤਜ਼ਰਬਾ ਹੁੰਦਾ ਹੈ ਜੋ ਉਹ ਸਿਖਾਉਂਦੇ ਹਨ। ਡਾਂਸ ਮਾਸਟਰ ਪਹਿਲਾਂ ਆਪਣਾ-ਆਪ ਬਣਾਉਂਦੇ ਹਨ ਅਤੇ ਬਾਅਦ ਵਿੱਚ ਡਾਂਸ ਪ੍ਰੋਗਰਾਮਾਂ ਨਾਲ ਇੱਕ ਡਾਂਸ ਸਕੂਲ ਸਥਾਪਿਤ ਕਰਦੇ ਹਨ।\nਕੋਰੀਓਗ੍ਰਾਫਰ ਅਕਸਰ ਯੂਨੀਵਰਸਿਟੀ ਨੂੰ ਸਿਖਲਾਈ ਕਰਾਉਂਦੇ ਹਨ ਅਤੇ ਖ਼ਾਸ ਤੌਰ ਤੇ ਖ਼ਾਸ ਪ੍ਰੋਜੇਕਟ ਲਈ ਕੰਮ ਕਰਦੇ ਹਨ ਅਤੇ ਕਈ ਵਾਰ ਇੱਕ ਡਾਂਸ ਕੰਪਨੀ ਵਲੋਂ ਇਕਰਾਰਨਾਮਾ ਕਰ ਕੇ ਉਹ ਕੰਪਨੀ ਵਲੋਂ ਪ੍ਰਤਿਨਿਧ ਕੋਰੀਓਗ੍ਰਾਫਰ ਬਣਕੇ ਠੇਕੇ ਤੇ ਕੰਮ ਕਰਦੇ ਹਨ।\n'
